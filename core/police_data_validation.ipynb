# %%
# Importing modules
import pandas as pd

# Read police Excel data into pandas ExcelFile
xl = pd.ExcelFile('../data/pfafinalmar22.xls')
# Store sheets as dataframes in dictionary
df = {}
for sheet in xl.sheet_names:
    df[f'{sheet}']= pd.read_excel(xl,sheet_name=sheet)
# Display sheet names
display(df.keys())
# Inspect first 10 rows of 'Table P1'
table_p1 = df['Table P1']
display(table_p1.head(10))
# Reassign header to row 5 and delete all rows before the header
header = table_p1.iloc[5]
table_p1.columns = header
table_p1_updated = table_p1.iloc[6:]
display(table_p1_updated.head())
# Out:
# dict_keys(['Cover_sheet', 'Table of Contents', 'Notes', 'Table P1', 'Table P1a Jan- Mar 22', 'Table P2', 'Table P2a Jan - Mar 22', 'Table P3', 'Table P4 previous', 'Table P5 ', 'Table P6 Jan-Mar', 'Table P7 ', 'Table P8', 'Table P9 ', 'Table P10 ', 'Table P11', 'Table P12 ', 'Table P13 '])
#   Table P1:  Police recorded crime by offence group and police force area, England and Wales, number of offences, year ending March 2022 [note 1]  \
# 0  This worksheet contains one table. Some cells ...
# 1                            Link to notes worksheet
# 2  Police recorded crime data are not designated ...
# 3                          Link to Table of Contents
# 4       Source: Home Office - Police recorded crime
# 5                                          Area Code
# 6                                          K04000001
# 7                                          E92000001
# 8                                          E12000001
# 9                                          E23000013
#
# ...
