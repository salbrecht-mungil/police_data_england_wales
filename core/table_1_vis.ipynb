# %%
from df_year_22_validation import df_year_22_updated
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Drop index column
df_year_22_updated = df_year_22_updated.drop(labels = 'index', axis=1)
print(df_year_22_updated.keys())
# Creating a single figure with a number of subplots
fig = plt.figure(figsize=(10,25))
fig.subplots_adjust(hspace=0.2, wspace=0.2)
ax = fig.add_subplot(2, 1, 1)
sns.barplot(y = 'Area Name', x = 'Total crime excluding fraud', data = df_year_22_updated, ax=ax)
ax = fig.add_subplot(2, 1, 2)
sns.barplot(y = 'Area Name', x = 'Violence against the person', data = df_year_22_updated, ax=ax)
# ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.show()

# , ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12, ax13, ax14, ax15, ax16, ax17, ax18, ax19, ax20, ax21, ax22, ax23
# Out:
# Index(['Area Code', 'Area Name', 'Total crime excluding fraud',
#        'Violence against the person', 'Homicide', 'Violence with injury',
#        'Violence without injury', 'Stalking and harassment',
#        'Death or serious injury - unlawful driving', 'Sexual offences',
#        'Robbery', 'Theft offences', 'Burglary', 'Residential burglary',
#        'Non-Residential burglary', 'Vehicle offences', 'Theft from the person',
#        'Bicycle theft', 'Shoplifting', 'Other theft offences',
#        'Criminal damage and arson', 'Drug offences',
#        'Possession of weapons offences', 'Public order offences',
#        'Miscellaneous crimes'],
#       dtype='object', name=5)
